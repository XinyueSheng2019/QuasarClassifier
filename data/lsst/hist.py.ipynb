# %%
import numpy as np 
import pandas as pd 
import csv
import matplotlib.pyplot as plt 
from matplotlib.pylab import *
from scipy.stats import norm
import matplotlib.mlab as mlab

# %%
data1 = pd.read_csv('preprocessed_data/batch2_converted_AGN.csv')
data2 = pd.read_csv('preprocessed_data/batch3_converted_AGN.csv')
data3 = pd.read_csv('preprocessed_data/batch4_converted_AGN.csv')
data4 = pd.read_csv('preprocessed_data/batch5_converted_AGN.csv')
data5 = pd.read_csv('preprocessed_data/batch6_converted_AGN.csv')
data6 = pd.read_csv('preprocessed_data/batch7_converted_AGN.csv')
data7 = pd.read_csv('preprocessed_data/batch8_converted_AGN.csv')
data8 = pd.read_csv('preprocessed_data/batch9_converted_AGN.csv')
data9 = pd.read_csv('preprocessed_data/batch10_converted_AGN.csv')
data10 = pd.read_csv('preprocessed_data/batch11_converted_AGN.csv')
data11 = pd.read_csv('preprocessed_data/training_converted_AGN.csv')

frames = [data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11]
data = pd.concat(frames, ignore_index = True)

# %%
labelsize = 20

# %%
u_list = data['u'].dropna()
n, bins, patches = plt.hist(u_list,bins=1000, range=(-500,500), density=1)
plt.ylabel('Probability', fontsize=labelsize)
plt.xlabel('u band (flux)', fontsize=labelsize)
plt.show()

# %%
ue_list = data['u_err'].dropna()
plt.hist(ue_list,bins=500, range=(-100,100), density=1)
plt.xlabel('u_err band (flux)', fontsize=labelsize)
plt.ylabel('Probability', fontsize=labelsize)
plt.show()

# %%
plt.scatter(data['u'], data['u_err'])
plt.xlabel('u band', fontsize=labelsize)
plt.ylabel('err', fontsize=labelsize)
# Out:
# Text(0, 0.5, 'err')

# %%
g_list = data['g'].dropna()
plt.hist(g_list,bins=500,range=(-500,500),density=1)
plt.xlabel('g band (flux)', fontsize=labelsize)
plt.ylabel('Probability', fontsize=labelsize)
plt.show()

# %%
ge_list = data['g_err'].dropna()
plt.hist(ge_list,bins=500, range=(-100,100), density=1)
plt.xlabel('g_err band (flux)', fontsize=labelsize)
plt.ylabel('Probability', fontsize=labelsize)
plt.show()

# %%
plt.scatter(data['g'], data['g_err'])
plt.xlabel('g band', fontsize=labelsize)
plt.ylabel('err', fontsize=labelsize)
# Out:
# Text(0, 0.5, 'err')

# %%
r_list = data['r'].dropna()
plt.hist(r_list,bins=500,range=(-500,500), density=1)
plt.xlabel('r band (flux)', fontsize=labelsize)
plt.ylabel('Probability', fontsize=labelsize)
plt.show()

# %%
re_list = data['r_err'].dropna()
plt.hist(re_list,bins=500, range=(-100,100), density=1)
plt.xlabel('r_err band (flux)', fontsize=labelsize)
plt.ylabel('Probability', fontsize=labelsize)
plt.show()

# %%
plt.scatter(data['r'], data['r_err'])
plt.xlabel('r band', fontsize=labelsize)
plt.ylabel('err', fontsize=labelsize)
plt.show()

# %%
i_list = data['i'].dropna()
plt.hist(i_list,bins=500,range=(-500,500), density=1)
plt.xlabel('i band (flux)', fontsize=labelsize)
plt.ylabel('Probability', fontsize=labelsize)
plt.show()

# %%
ie_list = data['i_err'].dropna()
plt.hist(ie_list,bins=500, range=(-100,100), density=1)
plt.xlabel('i_err band (flux)', fontsize=labelsize)
plt.ylabel('Probability', fontsize=labelsize)
plt.show()

# %%
plt.scatter(data['i'], data['i_err'])
plt.xlabel('i band', fontsize=labelsize)
plt.ylabel('err', fontsize=labelsize)
plt.show()

# %%
z_list = data['z'].dropna()
plt.hist(z_list,bins=500,range=(-500,500), density=1)
plt.xlabel('z band (flux)', fontsize=labelsize)
plt.ylabel('Probability', fontsize=labelsize)
plt.show()

# %%
ze_list = data['z_err'].dropna()
plt.hist(ze_list,bins=500, range=(-100,100), density=1)
plt.xlabel('z_err band (flux)', fontsize=labelsize)
plt.ylabel('Probability', fontsize=labelsize)
plt.show()

# %%
plt.scatter(data['z'], data['z_err'])
plt.xlabel('z band', fontsize=labelsize)
plt.ylabel('err', fontsize=labelsize)
plt.show()

# %%
y_list = data['y'].dropna()
plt.hist(y_list,bins=500,range=(-500,500), density=1)
plt.xlabel('y band (flux)', fontsize=labelsize)
plt.ylabel('Probability', fontsize=labelsize)
plt.show()

# %%
ye_list = data['y_err'].dropna()
plt.hist(ye_list,bins=500, range=(-100,100), density=1)
plt.xlabel('y_err band (flux)', fontsize=labelsize)
plt.ylabel('Probability', fontsize=labelsize)
plt.show()

# %%
plt.scatter(data['y'], data['y_err'])
plt.xlabel('y band', fontsize=labelsize)
plt.ylabel('err', fontsize=labelsize)
plt.show()

# %%
import seaborn as sns
internal_chars = ['u', 'u_err','g','g_err', 'r', 'r_err', 'i', 'i_err','z','z_err','y','y_err']
# pre_data = data[internal_chars]
corrmat = data[internal_chars].corr()
f, ax = plt.subplots(figsize=(30, 30))
sns.set(font_scale=1.8)
sns.heatmap(corrmat, square=True, linewidths=.5, annot=True,annot_kws={"size": 20},cmap="Blues",cbar_kws={"shrink": 0.82})
plt.savefig('correlation_colour.png')
plt.show()
