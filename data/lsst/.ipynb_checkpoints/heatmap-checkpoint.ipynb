# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('test_01_converted.csv')
id_list = []
combine = data.groupby(data['id'])
for _id, group in combine:
	id_list.append(_id)

mjd_list = data['mjd']
mjd_max = np.nanmax(mjd_list)
mjd_min = np.nanmin(mjd_list)
# max_obj = 4000

print("the time range is from %d to %d (day)"% (mjd_min,mjd_max))
use_mjd = [x for x in range(int(mjd_min),int(mjd_max))]

# pick max_obj number of objects and sort them by their redshift
# obj = None
# n = 0
# num_obj =0
# while n < len(data):
#     if data['object_id'][n]!=obj:
#         obj=data['object_id'][n]
#         num_obj +=1
#     n +=1

#convert to the obj id in the plot for convenience
map_obj = {}
n = 0
for i in id_list:
    map_obj[i] = n
    n +=1
# Out:
# the time range is from 59582 to 60674 (day)

# %%
n = 0
obj = None
data_mag = []

df = []
for i in id_list:
    mag_list = []
    ind_list = data[data.id == i].index.tolist()
    mjd_exit_list = data['mjd'][ind_list].tolist()
    mjd_exit_list = [int(x) for x in mjd_exit_list]
    
    m = 0
    while m<len(use_mjd):
        if use_mjd[m] in mjd_exit_list:
            mag = data['g'][ind_list[mjd_exit_list.index(use_mjd[m])]]
            if mag == None:
                mag = np.nan
            mag_list.append(mag)
        else:
            mag_list.append(np.nan)
        m +=1
    df.append(mag_list)

# %%
# df2 = pd.DataFrame(np.array(df))
test = np.array(df)
print(test.shape)
f, ax = plt.subplots(figsize=(32, 16))
# plt.figure(figsize = (32,16))
ax = sns.heatmap(test, cmap='Reds_r',vmin=15,vmax=25, label='g magnitude')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# sns.set_label('g magnitude',fontsize=24)
cax = plt.gcf().axes[-1]
cax.tick_params(labelsize=20)
#设置colorbar的label文本和字体大小
cbar = ax.collections[0].colorbar
cbar.set_label('g magnitude',fontsize=24)

locs, labels = plt.xticks()
print(locs)
print(labels)
# x_tick = np.linspace(0,2848,50)
x_label = [str(int(x)) for x in x_tick]
# print(x_tick)
print(x_label)
plt.xticks(x_tick, x_label, fontsize=20)
plt.yticks([])

plt.xlabel('days from earliest observation', fontsize=24, labelpad=10)
plt.ylabel('object sorted by redshift', fontsize=24)
plt.savefig('heatmap_g_test01.png')
# Out:
# (32926, 1092)
# [5.0000e-01 8.5000e+00 1.6500e+01 2.4500e+01 3.2500e+01 4.0500e+01
#  4.8500e+01 5.6500e+01 6.4500e+01 7.2500e+01 8.0500e+01 8.8500e+01
#  9.6500e+01 1.0450e+02 1.1250e+02 1.2050e+02 1.2850e+02 1.3650e+02
#  1.4450e+02 1.5250e+02 1.6050e+02 1.6850e+02 1.7650e+02 1.8450e+02
#  1.9250e+02 2.0050e+02 2.0850e+02 2.1650e+02 2.2450e+02 2.3250e+02
#  2.4050e+02 2.4850e+02 2.5650e+02 2.6450e+02 2.7250e+02 2.8050e+02
#  2.8850e+02 2.9650e+02 3.0450e+02 3.1250e+02 3.2050e+02 3.2850e+02
#  3.3650e+02 3.4450e+02 3.5250e+02 3.6050e+02 3.6850e+02 3.7650e+02
#  3.8450e+02 3.9250e+02 4.0050e+02 4.0850e+02 4.1650e+02 4.2450e+02
#  4.3250e+02 4.4050e+02 4.4850e+02 4.5650e+02 4.6450e+02 4.7250e+02
#  4.8050e+02 4.8850e+02 4.9650e+02 5.0450e+02 5.1250e+02 5.2050e+02
#  5.2850e+02 5.3650e+02 5.4450e+02 5.5250e+02 5.6050e+02 5.6850e+02
#  5.7650e+02 5.8450e+02 5.9250e+02 6.0050e+02 6.0850e+02 6.1650e+02
#  6.2450e+02 6.3250e+02 6.4050e+02 6.4850e+02 6.5650e+02 6.6450e+02
#  6.7250e+02 6.8050e+02 6.8850e+02 6.9650e+02 7.0450e+02 7.1250e+02
#  7.2050e+02 7.2850e+02 7.3650e+02 7.4450e+02 7.5250e+02 7.6050e+02
#  7.6850e+02 7.7650e+02 7.8450e+02 7.9250e+02 8.0050e+02 8.0850e+02
#  8.1650e+02 8.2450e+02 8.3250e+02 8.4050e+02 8.4850e+02 8.5650e+02
#  8.6450e+02 8.7250e+02 8.8050e+02 8.8850e+02 8.9650e+02 9.0450e+02
#  9.1250e+02 9.2050e+02 9.2850e+02 9.3650e+02 9.4450e+02 9.5250e+02
#  9.6050e+02 9.6850e+02 9.7650e+02 9.8450e+02 9.9250e+02 1.0005e+03
#  1.0085e+03 1.0165e+03 1.0245e+03 1.0325e+03 1.0405e+03 1.0485e+03
#  1.0565e+03 1.0645e+03 1.0725e+03 1.0805e+03 1.0885e+03]
# <a list of 137 Text xticklabel objects>
# [   0.           58.12244898  116.24489796  174.36734694  232.48979592
#   290.6122449   348.73469388  406.85714286  464.97959184  523.10204082
#   581.2244898   639.34693878  697.46938776  755.59183673  813.71428571
#   871.83673469  929.95918367  988.08163265 1046.20408163 1104.32653061
#  1162.44897959 1220.57142857 1278.69387755 1336.81632653 1394.93877551
#  1453.06122449 1511.18367347 1569.30612245 1627.42857143 1685.55102041
#  1743.67346939 1801.79591837 1859.91836735 1918.04081633 1976.16326531
#  2034.28571429 2092.40816327 2150.53061224 2208.65306122 2266.7755102
#  2324.89795918 2383.02040816 2441.14285714 2499.26530612 2557.3877551
#  2615.51020408 2673.63265306 2731.75510204 2789.87755102 2848.        ]
# ['0', '58', '116', '174', '232', '290', '348', '406', '464', '523', '581', '639', '697', '755', '813', '871', '929', '988', '1046', '1104', '1162', '1220', '1278', '1336', '1394', '1453', '1511', '1569', '1627', '1685', '1743', '1801', '1859', '1918', '1976', '2034', '2092', '2150', '2208', '2266', '2324', '2383', '2441', '2499', '2557', '2615', '2673', '2731', '2789', '2848']
